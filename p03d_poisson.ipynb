# %% [markdown]
# <a href="https://colab.research.google.com/github/kamal0803/CS299_ML_2018/blob/main/p03d_poisson.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df_train = pd.read_csv('ds4_train.csv')

# %%
df_train
# Out:
#       x_1  x_2       x_3       x_4         y
# 0     1.0  0.0  0.992047  0.325741   2463097
# 1     0.0  1.0  0.470463  0.371866    645481
# 2     0.0  1.0  0.496533  0.289853    474123
# 3     0.0  1.0  0.196377  0.694672   1542136
# 4     0.0  1.0  0.224992  0.880809   3705439
# ...   ...  ...       ...       ...       ...
# 2495  0.0  1.0  0.041959  0.475438    432141
# 2496  0.0  1.0  0.942358  0.226983    875413
# 2497  0.0  1.0  0.573173  0.428406   1016002
# 2498  0.0  1.0  0.601166  0.949115  10620315
# 2499  0.0  1.0  0.324601  0.405095    558245
#
# [2500 rows x 5 columns]

# %%
X = df_train.iloc[:, :-1].values
y = df_train.iloc[:, -1:].values
m, n = X.shape

# %%
# taking random values of theta, and transforming it to a n x 1 matrix
theta = np.ones(n).reshape(-1, 1)

# %%
theta.shape
# Out:
# (4, 1)

# %%
def compute_natural_parameter(X, theta):

  eta = np.exp(np.dot(X, theta))

  return eta

# %%
alpha = 1e-7

# %%
for i in range(100000):

  # gradient ascent algorithm to iteratively calculate theta
  theta = theta + alpha*np.dot(X.T, (y - compute_natural_parameter(X, theta)))/m

# %%
theta
# Out:
# array([[11.29995312],
#        [10.79992304],
#        [ 2.00006   ],
#        [ 4.4000118 ]])

# %%
# to predict values of y
# y = np.exp(np.dot(X, theta))
